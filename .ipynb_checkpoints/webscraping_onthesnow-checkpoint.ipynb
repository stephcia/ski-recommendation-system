# %%
#beautiful soup imports
from requests import get
from requests.exceptions import RequestException
from contextlib import closing
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import re
import time
import random
from time import sleep

# %% [markdown]
# # OnTheSnow Webscraping

# %% [markdown]
# Importing a list of URLS that has been pulled from [github](https://github.com/SijiaLai/OnTheSnow/tree/master) and later updated in excel to include additional resorts.

# %%
#importing
url_df = pd.read_csv('data/on_the_snow_url.csv')

# %%
url_df
# Out:
#                                                    url
# 0    https://www.onthesnow.com/california/squaw-val...
# 1    https://www.onthesnow.com/california/mammoth-m...
# 2    https://www.onthesnow.com/california/donner-sk...
# 3    https://www.onthesnow.com/california/sugar-bow...
# 4    https://www.onthesnow.com/california/kirkwood/...
# ..                                                 ...
# 332  https://www.onthesnow.com/oregon/mt-bachelor/s...
# 333  https://www.onthesnow.com/michigan/mount-bohem...
# 334  https://www.onthesnow.com/pennsylvania/shawnee...
# 335  https://www.onthesnow.com/massachusetts/wachus...
# 336  https://www.onthesnow.com/vermont/magic-mounta...
#
# [337 rows x 1 columns]

# %%
#saving urls as a list
url_list = url_df['url'].tolist()

# %% [markdown]
# To begin, I made a function that parses through the list of links and checks to see if they're still active. If they were not active, I manually updated the links in the url csv.

# %%
#making a list of all urls and removing .html to test links
test_df = url_df.replace(".html", "", regex=True)
test_list = test_df['url'].tolist()

# %%
#making a function to check if all links are active
def check_link_status(link):
    try:
        response = requests.head(link, timeout=5)
        return response.status_code == 200
    except requests.exceptions.RequestException:
        return False

# %%
#checking to see if all links are active
for link in test_list:
    if check_link_status(link):
        print(f"{link} is active.")
    else:
        print(f"{link} is not active or cannot be reached.")
# Out:
# https://www.onthesnow.com/california/squaw-valley-usa/ski-resort is active.
# https://www.onthesnow.com/california/mammoth-mountain-ski-area/ski-resort is active.
# https://www.onthesnow.com/california/donner-ski-ranch/ski-resort is active.
# https://www.onthesnow.com/california/sugar-bowl-resort/ski-resort is active.
# https://www.onthesnow.com/california/kirkwood/ski-resort is active.
# https://www.onthesnow.com/california/boreal/ski-resort is active.
# https://www.onthesnow.com/california/sierra-at-tahoe/ski-resort is active.
# https://www.onthesnow.com/nevada/mt-rose-ski-tahoe/ski-resort is active.
# https://www.onthesnow.com/california/soda-springs/ski-resort is active.
# https://www.onthesnow.com/colorado/wolf-creek-ski-area/ski-resort is active.
# https://www.onthesnow.com/washington/49-degrees-north/ski-resort is active.
# https://www.onthesnow.com/california/bear-valley/ski-resort is active.
# https://www.onthesnow.com/utah/alta-ski-area/ski-resort is active.
# https://www.onthesnow.com/oregon/mt-hood-meadows/ski-resort is active.
# https://www.onthesnow.com/utah/snowbird/ski-resort is active.
# https://www.onthesnow.com/california/northstar-california/ski-resort is active.
# https://www.onthesnow.com/washington/mt-baker/ski-resort is active.
# https://www.onthesnow.com/washington/alpental/ski-resort is active.
# https://www.onthesnow.com/california/tahoe-donner/ski-resort is active.
# https://www.onthesnow.com/washington/mt-spokane-ski-and-snowboard-park/ski-resort is active.
# https://www.onthesnow.com/utah/snowbasin/ski-resort is active.
# https://www.onthesnow.com/utah/brighton-resort/ski-resort is active.
# https://www.onthesnow.com/alaska/alyeska-resort/ski-resort is active.
# https://www.onthesnow.com/idaho/brundage-mountain-resort/ski-resort is active.
# https://www.onthesnow.com/california/dodge-ridge/ski-resort is active.
# https://www.onthesnow.com/oregon/mt-bachelor/ski-resort is active.
# https://www.onthesnow.com/utah/solitude-mountain-resort/ski-resort is active.
# https://www.onthesnow.com/oregon/mount-ashland/ski-resort is active.
# https://www.onthesnow.com/california/heavenly-mountain-resort/ski-resort is active.
# https://www.onthesnow.com/oregon/timberline-lodge/ski-resort is active.
# https://www.onthesnow.com/california/june-mountain/ski-resort is active.
# https://www.onthesnow.com/california/mount-shasta-board-ski-park/ski-resort is active.
# https://www.onthesnow.com/oregon/willamette-pass/ski-resort is active.
# https://www.onthesnow.com/utah/deer-valley-resort/ski-resort is active.
# https://www.onthesnow.com/colorado/silverton-mountain/ski-resort is active.
# https://www.onthesnow.com/utah/park-city-mountain-resort/ski-resort is active.
# https://www.onthesnow.com/nevada/diamond-peak/ski-resort is active.
# https://www.onthesnow.com/north-carolina/appalachian-ski-mtn/ski-resort is active.
# https://www.onthesnow.com/wyoming/grand-targhee-resort/ski-resort is active.
# https://www.onthesnow.com/wyoming/jackson-hole/ski-resort is active.
# https://www.onthesnow.com/idaho/lookout-pass-ski-area/ski-resort is active.
# https://www.onthesnow.com/utah/powder-mountain/ski-resort is active.
# https://www.onthesnow.com/colorado/aspen-snowmass/ski-resort is active.
# https://www.onthesnow.com/colorado/copper-mountain-resort/ski-resort is active.
# https://www.onthesnow.com/colorado/steamboat/ski-resort is active.
# https://www.onthesnow.com/idaho/pebble-creek-ski-area/ski-resort is active.
# https://www.onthesnow.com/arizona/arizona-snowbowl/ski-resort is active.
# https://www.onthesnow.com/colorado/telluride/ski-resort is active.
# https://www.onthesnow.com/minnesota/welch-village/ski-resort is active.
# https://www.onthesnow.com/new-mexico/taos-ski-valley/ski-resort is active.
# https://www.onthesnow.com/colorado/monarch-mountain/ski-resort is active.
# https://www.onthesnow.com/utah/sundance/ski-resort is active.
# https://www.onthesnow.com/colorado/durango-mountain-resort/ski-resort is active.
# https://www.onthesnow.com/colorado/breckenridge/ski-resort is active.
# https://www.onthesnow.com/colorado/winter-park-resort/ski-resort is active.
# https://www.onthesnow.com/washington/crystal-mountain-wa/ski-resort is active.
# https://www.onthesnow.com/washington/white-pass/ski-resort is active.
# https://www.onthesnow.com/montana/big-sky-resort/ski-resort is active.
# https://www.onthesnow.com/colorado/ski-cooper/ski-resort is active.
# https://www.onthesnow.com/colorado/powderhorn/ski-resort is active.
# https://www.onthesnow.com/idaho/schweitzer/ski-resort is active.
# https://www.onthesnow.com/colorado/crested-butte-mountain-resort/ski-resort is active.
# https://www.onthesnow.com/washington/stevens-pass-resort/ski-resort is active.
# https://www.onthesnow.com/washington/the-summit-at-snoqualmie/ski-resort is active.
# https://www.onthesnow.com/michigan/blackjack-ski-resort/ski-resort is active.
# https://www.onthesnow.com/utah/brian-head-resort/ski-resort is active.
# https://www.onthesnow.com/michigan/indianhead-mountain/ski-resort is active.
# https://www.onthesnow.com/oregon/hoodoo-ski-area/ski-resort is active.
# https://www.onthesnow.com/washington/bluewood/ski-resort is active.
# https://www.onthesnow.com/utah/beaver-mountain/ski-resort is active.
# https://www.onthesnow.com/idaho/bogus-basin/ski-resort is active.
# https://www.onthesnow.com/montana/lost-trail-powder-mtn/ski-resort is active.
# https://www.onthesnow.com/minnesota/wild-mountain-ski-snowboard-area/ski-resort is active.
# https://www.onthesnow.com/montana/whitefish-mountain-resort/ski-resort is active.
# https://www.onthesnow.com/montana/blacktail-mountain-ski-area/ski-resort is active.
# https://www.onthesnow.com/colorado/arapahoe-basin-ski-area/ski-resort is active.
# https://www.onthesnow.com/new-mexico/ski-santa-fe/ski-resort is active.
# https://www.onthesnow.com/colorado/vail/ski-resort is active.
# https://www.onthesnow.com/oregon/anthony-lakes-mountain-resort/ski-resort is active.
# https://www.onthesnow.com/colorado/loveland/ski-resort is active.
# https://www.onthesnow.com/idaho/sun-valley/ski-resort is active.
# https://www.onthesnow.com/colorado/beaver-creek/ski-resort is active.
# https://www.onthesnow.com/vermont/bolton-valley/ski-resort is active.
# https://www.onthesnow.com/montana/montana-snowbowl/ski-resort is active.
# https://www.onthesnow.com/wisconsin/trollhaugen/ski-resort is active.
# https://www.onthesnow.com/montana/bridger-bowl/ski-resort is active.
# https://www.onthesnow.com/colorado/keystone/ski-resort is active.
# https://www.onthesnow.com/wisconsin/granite-peak-ski-area/ski-resort is active.
# https://www.onthesnow.com/idaho/silver-mountain/ski-resort is active.
# https://www.onthesnow.com/montana/discovery-ski-area/ski-resort is active.
# https://www.onthesnow.com/michigan/mont-ripley/ski-resort is active.
# https://www.onthesnow.com/california/snow-valley/ski-resort is active.
# https://www.onthesnow.com/colorado/sunlight-mountain-resort/ski-resort is active.
# https://www.onthesnow.com/nevada/las-vegas-ski-and-snowboard-resort/ski-resort is active.
# https://www.onthesnow.com/oregon/mt-hood-ski-bowl/ski-resort is active.
# https://www.onthesnow.com/california/ski-china-peak/ski-resort is active.
# https://www.onthesnow.com/montana/red-lodge-mountain/ski-resort is active.
# https://www.onthesnow.com/new-hampshire/cannon-mountain/ski-resort is active.
# https://www.onthesnow.com/minnesota/lutsen-mountains/ski-resort is active.
# https://www.onthesnow.com/new-jersey/mountain-creek-resort/ski-resort is active.
# https://www.onthesnow.com/wyoming/snowy-range-ski-recreation-area/ski-resort is active.
# https://www.onthesnow.com/massachusetts/wachusett-mountain-ski-area/ski-resort is active.
# https://www.onthesnow.com/michigan/boyne-mountain-resort/ski-resort is active.
# https://www.onthesnow.com/michigan/ski-brule/ski-resort is active.
# https://www.onthesnow.com/montana/great-divide/ski-resort is active.
# https://www.onthesnow.com/minnesota/giants-ridge-resort/ski-resort is active.
# https://www.onthesnow.com/vermont/jay-peak/ski-resort is active.
# https://www.onthesnow.com/washington/mission-ridge/ski-resort is active.
# https://www.onthesnow.com/pennsylvania/camelback-mountain-resort/ski-resort is active.
# https://www.onthesnow.com/new-hampshire/black-mountain/ski-resort is active.
# https://www.onthesnow.com/colorado/eldora-mountain-resort/ski-resort is active.
# https://www.onthesnow.com/montana/maverick-mountain/ski-resort is active.
# https://www.onthesnow.com/montana/showdown-ski-area/ski-resort is active.
# https://www.onthesnow.com/new-york/song-mountain/ski-resort is active.
# https://www.onthesnow.com/vermont/stowe-mountain-resort/ski-resort is active.
# https://www.onthesnow.com/pennsylvania/big-boulder/ski-resort is active.
# https://www.onthesnow.com/minnesota/buck-hill/ski-resort is active.
# https://www.onthesnow.com/michigan/crystal-mountain/ski-resort is active.
# https://www.onthesnow.com/vermont/killington-resort/ski-resort is active.
# https://www.onthesnow.com/michigan/shanty-creek/ski-resort is active.
# https://www.onthesnow.com/vermont/smugglers-notch-resort/ski-resort is active.
# https://www.onthesnow.com/new-hampshire/wildcat-mountain/ski-resort is active.
# https://www.onthesnow.com/new-mexico/sipapu-ski-and-summer-resort/ski-resort is active.
# https://www.onthesnow.com/new-hampshire/bretton-woods/ski-resort is active.
# https://www.onthesnow.com/michigan/nubs-nob-ski-area/ski-resort is active.
# https://www.onthesnow.com/michigan/treetops-resort/ski-resort is active.
# https://www.onthesnow.com/california/bear-mountain/ski-resort is active.
# https://www.onthesnow.com/wyoming/hogadon/ski-resort is active.
# https://www.onthesnow.com/massachusetts/jiminy-peak/ski-resort is active.
# https://www.onthesnow.com/new-hampshire
ski-resort is active.
# https://www.onthesnow.com/pennsylvania/mount-pleasant-of-edinboro/ski-resort is active.
# https://www.onthesnow.com/new-york/hunt-hollow-ski-club/ski-resort is active.
# https://www.onthesnow.com/connecticut/powder-ridge-park/ski-resort is active.
# https://www.onthesnow.com/washington/mission-ridge/ski-resort is active.
# https://www.onthesnow.com/oregon/mt-bachelor/ski-resort is active.
# https://www.onthesnow.com/michigan/mount-bohemia/ski-resort is active.
# https://www.onthesnow.com/pennsylvania/shawnee-mountain-ski-area/ski-resort is active.
# https://www.onthesnow.com/massachusetts/wachusett-mountain-ski-area/ski-resort is active.
# https://www.onthesnow.com/vermont/magic-mountain/ski-resort is active.

# %% [markdown]
# This code was also adapted from the same github user. I updated the code as not all of the html elements were still the same, and included additional features that I wanted to scrape.

# %%
def is_good_response(resp):
    """
    Ensures that the response is a html.
    """
    content_type = resp.headers['Content-Type'].lower()
    return (resp.status_code == 200 and
            content_type is not None
            and content_type.find('html') > -1)

def get_html_content(url):
    """
    Get the contents of the url.
    """
    time.sleep(1)
    try:
        with closing(get(url, stream=True)) as resp:
            content_type = resp.headers['Content-Type'].lower()
            if is_good_response(resp):
                return resp.content
            else:
                raise RequestException('Error: Received status code {0} for URL {1}'.format(resp.status_code, url))
    except RequestException as e:
        print('Error during requests to {0} : {1}'.format(url, str(e)))
        raise

def get_basic_resort_statistics(resortUrl):
    """
    Get basic stat for the ski resort.
    """
    resortContent = get_html_content(resortUrl)
    resortHtml = BeautifulSoup(resortContent, 'html.parser')

    stat = {}

    #Name
    if (resortHtml.find("span",{"class":"styles_resort__1wghR"}) != None):
        resortNameContent = resortHtml.find("span",{"class":"styles_resort__1wghR"})
        resortName = resortNameContent.get_text()
        stat["ski_resort"] = resortName
    else:
        nameNote = "Check name info."
        stat["name_note"] = nameNote

    # Locations
    if resortHtml.find("div", {"class": "styles_address__1Mkk8"}) is not None:
        resortLocationContent = resortHtml.find("div", {"class": "styles_address__1Mkk8"})
        address_elements = resortLocationContent.find_all("p")
        if len(address_elements) >= 3:
            address = address_elements[0].get_text()
            city_state = address_elements[1].get_text().split(",")
            city = city_state[0].strip()
            state = city_state[1].strip()
            country = address_elements[2].get_text()
            stat["address"] = address
            stat["city"] = city
            stat["state"] = state
            stat["country"] = country
        
        else:
            locationNote = "Incomplete location info."
            stat["location_note"] = locationNote

    # Elevation
    if resortHtml.find("div", {"class": "styles_elevation__2L-EV"}) is not None:
        elevationContent = resortHtml.find("div", {"class": "styles_elevation__2L-EV"})
        elevationValues = elevationContent.find_all("div", {"class": "styles_inner__2bSAI"})
        keys = ["summit", "drop", "base"]
        for key, value in zip(keys, elevationValues):
            distance = value.find("div", {"class": "styles_distance__3eFw3"}).get_text().replace("'", "")
            distance = int(distance) if distance.isdigit() else None
            stat[key] = distance
    else:
        elevationNote = "Check elevation information."
        stat["elevation_note"] = elevationNote

    # Gondolas and Lifts
    if resortHtml.find("div", {"class": "styles_box__3XF8j", "title": "Gondolas & Trams"}) is not None:
        # Extract the number of trams
        trams_div = resortHtml.find("div", {"class": "styles_box__3XF8j", "title": "Gondolas & Trams"})
        trams_value = trams_div.find("div", {"class": "styles_value__fB0LV"}).text
        trams = float(trams_value)
        stat["gondolas_and_trams"] = trams

    if resortHtml.find("div", {"class": "styles_box__3XF8j", "title": "High Speed Quads"}) is not None:
        # Extract the number of fast eight lifts
        fast_eight_div = resortHtml.find("div", {"class": "styles_box__3XF8j", "title": "High Speed Quads"})
        fast_eight_value = fast_eight_div.find("div", {"class": "styles_value__fB0LV"}).text
        fast_eight = float(fast_eight_value)
        stat["fast_eight"] = fast_eight
        
    if resortHtml.find("div", {"class": "styles_box__3XF8j", "title": "High Speed Sixes"}) is not None:
        # Extract the number of high-speed sixes lifts
        high_speed_sixes_div = resortHtml.find("div", {"class": "styles_box__3XF8j", "title": "High Speed Sixes"})
        high_speed_sixes_value = high_speed_sixes_div.find("div", {"class": "styles_value__fB0LV"}).text
        high_speed_sixes = float(high_speed_sixes_value)
        stat["high_speed_sixes"] = high_speed_sixes

    if resortHtml.find("div", {"class": "styles_box__3XF8j", "title": "Quad Chairs"}) is not None:
        # Extract the number of quad chairs lifts
        quad_chairs_div = resortHtml.find("div", {"class": "styles_box__3XF8j", "title": "Quad Chairs"})
        quad_chairs_value = quad_chairs_div.find("div", {"class": "styles_value__fB0LV"}).text
        quad_chairs = float(quad_chairs_value)
        stat["quad_chairs"] = quad_chairs

    if resortHtml.find("div", {"class": "styles_box__3XF8j", "title": "Triple Chairs"}) is not None:
        # Extract the number of triple chairs lifts
        triple_chairs_div = resortHtml.find("div", {"class": "styles_box__3XF8j", "title": "Triple Chairs"})
        triple_chairs_value = triple_chairs_div.find("div", {"class": "styles_value__fB0LV"}).text
        triple_chairs = float(triple_chairs_value)
        stat["triple_chairs"] = triple_chairs
        
    if resortHtml.find("div", {"class": "styles_box__3XF8j", "title": "Double Chairs"}) is not None:
        # Extract the number of double_chairs lifts
        double_chairs_div = resortHtml.find("div", {"class": "styles_box__3XF8j", "title": "Double Chairs"})
        double_chairs_value = double_chairs_div.find("div", {"class": "styles_value__fB0LV"}).text
        double_chairs = float(double_chairs_value)
        stat["double_chairs"] = double_chairs 
        
    if resortHtml.find("div", {"class": "styles_box__3XF8j", "title": "Surface Lifts"}) is not None:
        # Extract the number of triple chairs lifts
        surface_lifts_div = resortHtml.find("div", {"class": "styles_box__3XF8j", "title": "Surface Lifts"})
        surface_lifts_value = surface_lifts_div.find("div", {"class": "styles_value__fB0LV"}).text
        surface_lifts = float(surface_lifts_value)
        stat["surface_lifts"] = surface_lifts  
        
    else:
        gondolas_lifts_note = "Check gondola information."
        stat["gondolas_lifts_note"] = gondolas_lifts_note

    #Terrain
    if resortHtml.find("div", {"class": "styles_box__3XF8j", "title": "Runs in Total"}) is not None:
        # Extract the number of runs
        run_div = resortHtml.find("div", {"class": "styles_box__3XF8j", "title": "Runs in Total"})
        run_value = run_div.find("div", {"class": "styles_value__fB0LV"}).text
        run = float(run_value)
        stat["total_runs"] = run
        
    if resortHtml.find("div", {"class": "styles_box__3XF8j", "title": "Longest Run"}) is not None:
        # Extract the longest run
        longest_run_div = resortHtml.find("div", {"class": "styles_box__3XF8j", "title": "Longest Run"})
        longest_run_value = longest_run_div.find("div", {"class": "styles_value__fB0LV"}).text
        longest_run = str(longest_run_value)
        stat["longest_run"] = longest_run
        
    if resortHtml.find("div", {"class": "styles_box__3XF8j", "title": "Skiable Terrain"}) is not None:
        # Extract the skiable terrain
        skiable_div = resortHtml.find("div", {"class": "styles_box__3XF8j", "title": "Skiable Terrain"})
        skiable_value = skiable_div.find("div", {"class": "styles_value__fB0LV"}).text
        skiable = str(skiable_value)
        stat["skiable_terrain"] = skiable
        
    if resortHtml.find("div", {"class": "styles_box__3XF8j", "title": "Snow Making"}) is not None:
        # Extract the snow making
        snowmak_div = resortHtml.find("div", {"class": "styles_box__3XF8j", "title": "Snow Making"})
        snowmak_value = snowmak_div.find("div", {"class": "styles_value__fB0LV"}).text
        snowmak = str(snowmak_value)
        stat["snow_making"] = snowmak
        
    if resortHtml.find("div", {"class": "styles_box__3XF8j", "title": "Beginners Runs"}) is not None:
        # Extract the snow making
        begrun_div = resortHtml.find("div", {"class": "styles_box__3XF8j", "title": "Beginners Runs"})
        begrun_value = begrun_div.find("div", {"class": "styles_value__fB0LV"}).text
        begrun = str(begrun_value)
        stat["beginner_runs"] = begrun
        
    if resortHtml.find("div", {"class": "styles_box__3XF8j", "title": "Beginners Runs"}) is not None:
        # Extract the snow making
        begrun_div = resortHtml.find("div", {"class": "styles_box__3XF8j", "title": "Beginners Runs"})
        begrun_value = begrun_div.find("div", {"class": "styles_value__fB0LV"}).text
        begrun = str(begrun_value)
        stat["beginner_runs"] = begrun
        
    if resortHtml.find("div", {"class": "styles_box__3XF8j", "title": "Intermediate Runs"}) is not None:
        # Extract the snow making
        intrun_div = resortHtml.find("div", {"class": "styles_box__3XF8j", "title": "Intermediate Runs"})
        intrun_value = intrun_div.find("div", {"class": "styles_value__fB0LV"}).text
        intrun = str(intrun_value)
        stat["intermediate_runs"] = intrun
        
    if resortHtml.find("div", {"class": "styles_box__3XF8j", "title": "Advanced Runs"}) is not None:
        # Extract the snow making
        advrun_div = resortHtml.find("div", {"class": "styles_box__3XF8j", "title": "Advanced Runs"})
        advrun_value = advrun_div.find("div", {"class": "styles_value__fB0LV"}).text
        advrun = str(advrun_value)
        stat["advanced_runs"] = advrun

    if resortHtml.find("div", {"class": "styles_box__3XF8j", "title": "Expert Runs"}) is not None:
        # Extract the snow making
        exprun_div = resortHtml.find("div", {"class": "styles_box__3XF8j", "title": "Expert Runs"})
        exprun_value = exprun_div.find("div", {"class": "styles_value__fB0LV"}).text
        exprun = str(exprun_value)
        stat["expert_runs"] = exprun      
        
    else:
        terrainNote = "Check terrain information."
        stat["terrain_note"] = terrainNote

    # Days Opened and Snowfall
    if resortHtml.find("div", class_="styles_importantDates__LELVC") is not None:
        important_dates = resortHtml.find("div", class_="styles_importantDates__LELVC")
        rows = important_dates.find_all("div", class_="styles_row__1t2pK")

        for row in rows:
            items = row.find_all("div", class_="styles_item__31bBH")

            for item in items:
                label = item.find("div").get_text(strip=True)
                value = item.find("span", class_="h3 styles_h3__OQalR").get_text(strip=True)

                if label == "Days Open Last Year":
                    daysOpenLastYear = value
                    stat["daysOpenLastYear"] = daysOpenLastYear
                elif label == "Average Snowfall":
                    averageSnowfall = value
                    stat["averageSnowfall"] = averageSnowfall
                    
    else:
        daysopenNote = "Check resort open information."
        stat["open_note"] = daysopenNote
        
        
    # Projected Opening
    if resortHtml.find("div", class_="styles_importantDates__LELVC") is not None:
        important_dates = resortHtml.find("div", class_="styles_importantDates__LELVC")
        rows = important_dates.find_all("div", class_="styles_row__1t2pK")

        for row in rows:
            items = row.find_all("div", class_="styles_item__31bBH")

            for item in items:
                label = item.find("div").get_text(strip=True)
                date_element = item.find("span", class_="styles_desktopDate__1Djk-")

                if date_element is not None:
                    value = date_element.get_text(strip=True)

                    if label == "Projected Opening":
                        projectedOpening = value
                        stat["projectedOpening"] = projectedOpening
                    elif label == "Projected Closing":
                        projectedClosing = value
                        stat["projectedClosing"] = projectedClosing          
    else:
        openNote = "Check resort opening/closing date information."
        stat["open_note"] = openNote

    # Check if  values weren't found
    if "daysOpenLastYear" not in stat:
        stat["days_open_note"] = "Check days info"
    if "projectedOpening" not in stat:
        stat["projected_opening_note"] = "Check projected opening info"
    if "averageSnowfall" not in stat:
        stat["average_snowfall_note"] = "Check average snowfall info"
    if "projectedClosing" not in stat:
        stat["projected_closing_note"] = "Check projected closing info"
        
    # Average Snowfall
    if resortHtml.find("div", class_="styles_box__1sXJN") is not None:
        monthly_snowfall = resortHtml.find("div", class_="styles_box__1sXJN")
        rows = monthly_snowfall.find_all("div", class_="styles_inner__3kHSq")

        for row in rows:
            label = row.find("div", class_="styles_date__ACGKW").get_text(strip=True)
            value = row.find("div", class_="styles_value__3uWEv").get_text(strip=True)

            if label == "Nov":
                stat["nov_snow"] = str(value)
            elif label == "Dec":
                stat["dec_snow"] = str(value)
            elif label == "Jan":
                stat["jan_snow"] = str(value)
            elif label == "Feb":
                stat["feb_snow"] = str(value)
            elif label == "Mar":
                stat["mar_snow"] = str(value)
            elif label == "Apr":
                stat["apr_snow"] = str(value)
            elif label == "May":
                stat["may_snow"] = str(value)

    else:
        averageSnowfallNote = "Check snowfall information."
        stat["snowfall_note"] = averageSnowfallNote
    
    return stat

def get_resort_prices(resortUrl):
    """
    Get the resort lift ticket prices.
    """
    prices = {}

    resortUrl = resortUrl[:-15] + "lift-tickets.html"
    priceContent = get_html_content(resortUrl)

    priceHtml = BeautifulSoup(priceContent, 'html.parser')
    priceData = priceHtml.find_all("span", class_="h4 styles_h4__1nbGO")

    for i, price in enumerate(priceData):
        value = str(price.get_text(strip=True))
        if i < 11:
            key = ""
            if i == 0:
                key = "child_season"
            elif i == 1:
                key = "junior_season"
            elif i == 2:
                key = "adult_season"
            elif i == 3:
                key = "child_weekday"
            elif i == 4:
                key = "junior_weekday"
            elif i == 5:
                key = "adult_weekday"
            elif i == 6:
                key = "senior_weekday"
            elif i == 7:
                key = "child_weekend"
            elif i == 8:
                key = "junior_weekend"
            elif i == 9:
                key = "adult_weekend"
            elif i == 10:
                key = "senior_weekend"

            prices[key] = value

    if len(priceData) < 1:
        ticketpriceNote = "Check ticket prices."
        stat["ticket_price_note"] = ticketpriceNote

    return prices

if __name__ == '__main__':
    """
    Extract data for each ski resort.
    """
    resortData = dict()
    
    for url in url_df['url'].head():
        resortUrl = url
        stat = get_basic_resort_statistics(resortUrl)
        prices = get_resort_prices(resortUrl)
        time.sleep(1)

        resortData[url] = {**stat, **prices, "Url": resortUrl}

    df = pd.DataFrame.from_dict(resortData, orient='index')
    #df.to_csv('data/OnTheSnow_Srape_2_200523.csv', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, https://www.onthesnow.com/california/squaw-valley-usa/ski-resort.html to https://www.onthesnow.com/california/kirkwood/ski-resort.html
# Data columns (total 48 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ski_resort           5 non-null      object
#  1   address              5 non-null      object
#  2   city                 5 non-null      object
#  3   state                5 non-null      object
#  4   country              5 non-null      object
#  5   summit               5 non-null      int64
#  6   drop                 5 non-null      int64
#  7   base                 5 non-null      int64
#  8   gondolas_and_trams   3 non-null      float64
#  9   fast_eight           4 non-null      float64
#  10  high_speed_sixes     2 non-null      float64
#  11  quad_chairs          4 non-null      float64
#  12  triple_chairs        5 non-null      float64
#  13  double_chairs        4 non-null      float64
#  14  surface_lifts        4 non-null      float64
#  15  total_runs           5 non-null      float64
#  16  longest_run          5 non-null      object
#  17  skiable_terrain      5 non-null      object
#  18  snow_making          5 non-null      object
#  19  terrain_note         2 non-null      object
#  20  daysOpenLastYear     5 non-null      object
#  21  averageSnowfall      5 non-null      object
#  22  projectedOpening     5 non-null      object
#  23  projectedClosing     5 non-null      object
#  24  nov_snow             5 non-null      object
#  25  dec_snow             5 non-null      object
#  26  jan_snow             5 non-null      object
#  27  feb_snow             5 non-null      object
#  28  mar_snow             5 non-null      object
#  29  apr_snow             5 non-null      object
#  30  may_snow             5 non-null      object
#  31  child_season         5 non-null      object
#  32  junior_season        5 non-null      object
#  33  adult_season         5 non-null      object
#  34  child_weekday        5 non-null      object
#  35  junior_weekday       4 non-null      object
#  36  adult_weekday        4 non-null      object
#  37  senior_weekday       4 non-null      object
#  38  child_weekend        4 non-null      object
#  39  junior_weekend       4 non-null      object
#  40  adult_weekend        4 non-null      object
#  41  senior_weekend       4 non-null      object
#  42  Url                  5 non-null      object
#  43  gondolas_lifts_note  1 non-null      object
#  44  beginner_runs        3 non-null      object
#  45  intermediate_runs    3 non-null      object
#  46  advanced_runs        3 non-null      object
#  47  expert_runs          3 non-null      object
# dtypes: float64(8), int64(3), object(37)
# memory usage: 1.9+ KB

# %%
df.head()
# Out:
#                                                           ski_resort  \
# https://www.onthesnow.com/california/squaw-vall...   Palisades Tahoe
# https://www.onthesnow.com/california/mammoth-mo...           Mammoth
# https://www.onthesnow.com/california/donner-ski...  Donner Ski Ranch
# https://www.onthesnow.com/california/sugar-bowl...        Sugar Bowl
# https://www.onthesnow.com/california/kirkwood/s...          Kirkwood
#
#                                                         address  \
# https://www.onthesnow.com/california/squaw-vall...  PO Box 2007
# https://www.onthesnow.com/california/mammoth-mo...  P.O. Box 24
# https://www.onthesnow.com/california/donner-ski...  P.O. Box 66
# https://www.onthesnow.com/california/sugar-bowl...   P.O. Box 5
# https://www.onthesnow.com/california/kirkwood/s...     PO Box 1
#
#                                                                     city  \
# https://www.onthesnow.com/california/squaw-vall...  96146 Olympic Valley
# https://www.onthesnow.com/california/mammoth-mo...   93546 Mammoth Lakes
# https://www.onthesnow.com/california/donner-ski...          95724 Norden
# https://www.onthesnow.com/california/sugar-bowl...          95724 Norden
# https://www.onthesnow.com/california/kirkwood/s...        95646 Kirkwood
#
#                                                          state        country  \
# https://www.onthesnow.com/california/squaw-vall...  California  United States
# https://www.onthesnow.com/california/mammoth-mo...  California  United States
# https://www.onthesnow.com/california/donner-ski...  California  United States
# https://www.onthesnow.com/california/sugar-bowl...  California  United States
# https://www.onthesnow.com/california/kirkwood/s...  California  United States
#
#                                                     summit  drop  base  \
# https://www.onthesnow.com/california/squaw-vall...    9050  2850  6200
# https://www.onthesnow.com/california/mammoth-mo...   11053  3100  7953
# https://www.onthesnow.com/california/donner-ski...    8012   750  7031
# https://www.onthesnow.com/california/sugar-bowl...    8383  1500  6883
# https://www.onthesnow.com/california/kirkwood/s...    9800  2000  7800
#
#                                                     gondolas_and_trams  \
# https://www.onthesnow.com/california/squaw-vall...                 3.0
# https://www.onthesnow.com/california/mammoth-mo...                 3.0
# https://www.onthesnow.com/california/donner-ski...                 NaN
# https://www.onthesnow.com/california/sugar-bowl...                 1.0
# https://www.onthesnow.com/california/kirkwood/s...                 NaN
#
#                                                     fast_eight  ...  \
# https://www.onthesnow.com/california/squaw-vall...         6.0  ...
# https://www.onthesnow.com/california/mammoth-mo...         9.0  ...
# https://www.onthesnow.com/california/donner-ski...         NaN  ...
# https://www.onthesnow.com/california/sugar-bowl...         5.0  ...
# https://www.onthesnow.com/california/kirkwood/s...         2.0  ...
#
#                                                     child_weekend  \
# https://www.onthesnow.com/california/squaw-vall...         160.00
# https://www.onthesnow.com/california/mammoth-mo...          81.00
# https://www.onthesnow.com/california/donner-ski...          89.00
# https://www.onthesnow.com/california/sugar-bowl...         103.00
# https://www.onthesnow.com/california/kirkwood/s...            NaN
#
#                                                     junior_weekend  \
# https://www.onthesnow.com/california/squaw-vall...          206.00
# https://www.onthesnow.com/california/mammoth-mo...          147.00
# https://www.onthesnow.com/california/donner-ski...           59.00
# https://www.onthesnow.com/california/sugar-bowl...           73.00
# https://www.onthesnow.com/california/kirkwood/s...             NaN
#
#                                                     adult_weekend  \
# https://www.onthesnow.com/california/squaw-vall...         229.00
# https://www.onthesnow.com/california/mammoth-mo...         179.00
# https://www.onthesnow.com/california/donner-ski...          89.00
# https://www.onthesnow.com/california/sugar-bowl...         103.00
# https://www.onthesnow.com/california/kirkwood/s...            NaN
#
#                                                     senior_weekend  \
# https://www.onthesnow.com/california/squaw-vall...          206.00
# https://www.onthesnow.com/california/mammoth-mo...          147.00
# https://www.onthesnow.com/california/donner-ski...           89.00
# https://www.onthesnow.com/california/sugar-bowl...          125.00
# https://www.onthesnow.com/california/kirkwood/s...             NaN
#
#                                                                                                   Url  \
# https://www.onthesnow.com/california/squaw-vall...  https://www.onthesnow.com/california/squaw-val...
# https://www.onthesnow.com/california/mammoth-mo...  https://www.onthesnow.com/california/mammoth-m...
# https://www.onthesnow.com/california/donner-ski...  https://www.onthesnow.com/california/donner-sk...
# https://www.onthesnow.com/california/sugar-bowl...  https://www.onthesnow.com/california/sugar-bow...
# https://www.onthesnow.com/california/kirkwood/s...  https://www.onthesnow.com/california/kirkwood/...
#
#                                                            gondolas_lifts_note  \
# https://www.onthesnow.com/california/squaw-vall...                         NaN
# https://www.onthesnow.com/california/mammoth-mo...  Check gondola information.
# https://www.onthesnow.com/california/donner-ski...                         NaN
# https://www.onthesnow.com/california/sugar-bowl...                         NaN
# https://www.onthesnow.com/california/kirkwood/s...                         NaN
#
#                                                    beginner_runs  \
# https://www.onthesnow.com/california/squaw-vall...           NaN
# https://www.onthesnow.com/california/mammoth-mo...           15%
# https://www.onthesnow.com/california/donner-ski...           31%
# https://www.onthesnow.com/california/sugar-bowl...           15%
# https://www.onthesnow.com/california/kirkwood/s...           NaN
#
#                                                    intermediate_runs  \
# https://www.onthesnow.com/california/squaw-vall...               NaN
# https://www.onthesnow.com/california/mammoth-mo...               48%
# https://www.onthesnow.com/california/donner-ski...               38%
# https://www.onthesnow.com/california/sugar-bowl...               45%
# https://www.onthesnow.com/california/kirkwood/s...               NaN
#
#                                                    advanced_runs expert_runs
# https://www.onthesnow.com/california/squaw-vall...           NaN         NaN
# https://www.onthesnow.com/california/mammoth-mo...           24%         13%
# https://www.onthesnow.com/california/donner-ski...           21%         10%
# https://www.onthesnow.com/california/sugar-bowl...           28%         12%
# https://www.onthesnow.com/california/kirkwood/s...           NaN         NaN
#
# [5 rows x 48 columns]
